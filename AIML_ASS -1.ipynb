# %% [markdown]
# Lab01- Implement basic data structures of Numpy, Pandas, Matplotlib and Access Data from sources
#
#
# Part 01: Lab Task is implement the following data structures using Numpy and Pandas.**
# 1. Lists
# 2. Arrays
# 3. Identify their type using type()
# 4. Perform mathematical operations on these datasets created multiplication,     division, poweroff
# 5. Combine text with Numpy fuction to generate a textual output - ”Addition of
#   Two: array1 +array 2
#   Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
list=[5,4,3,2,1]
print("List:",list)

array1=np.array([1,2,3,4,5])
array2=np.array([6,7,8,9,10])
print("Array1:",array1)
print("Array2:",array2)

print("Type of my list:",type(list))

a=array1+array2
print("Addition:",a)
b=array1-array2
print("Subtraction:",b)
c=array1*array2
print("Multiplication:",c)
d=array1/array2
print("Division:",d)

addition_result=array1+array2
print(f"Addition of two arrays:array1+array2={addition_result}")

sin_values=np.sin(array1)
print("Sine of array1:",sin_values)
log_values=np.log(array1)

log10 = np.log10(array1)
print("log10 values",log10)

log2 = np.log2(array1)
print("log2 values",log2)

exp = np.exp(array1)
print("exp values",exp)

sqrt = np.sqrt(array1)
print("sqrt values",sqrt)

sin = np.sin(array1)
print("sin values",sin)

cos = np.cos(array1)
print("cos values",cos)

tan = np.tan(array1)
print("tan values",tan)


print("Log of array1:",log_values)
exp_values=np.exp(array1)
print("Exponential of array1:",exp_values)
# Out:
# List: [5, 4, 3, 2, 1]
# Array1: [1 2 3 4 5]
# Array2: [ 6  7  8  9 10]
# Type of my list: <class 'list'>
# Addition: [ 7  9 11 13 15]
# Subtraction: [-5 -5 -5 -5 -5]
# Multiplication: [ 6 14 24 36 50]
# Division: [0.16666667 0.28571429 0.375      0.44444444 0.5       ]
# Addition of two arrays:array1+array2=[ 7  9 11 13 15]
# Sine of array1: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# log10 values [0.         0.30103    0.47712125 0.60205999 0.69897   ]
# log2 values [0.         1.         1.5849625  2.         2.32192809]
# exp values [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]
# sqrt values [1.         1.41421356 1.73205081 2.         2.23606798]
# sin values [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# cos values [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219]
# tan values [ 1.55740772 -2.18503986 -0.14254654  1.15782128 -3.38051501]
# Log of array1: [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# Exponential of array1: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %% [markdown]
# Part-02: Lab Task is to visualize the datasets or data using Matplotlib
#
# builtin function Graphs
#
# Generate Scatterplot

# %%
import matplotlib.pyplot as plt

people = ['kiran','arun','vijay','varun']
ages=["25,30,35,40"]
height=[145,151,165,173]
weight=[45,55,65,75]

plt.scatter(weight, height)
plt.title("relationship between weight and height :")
plt.ylabel("eight in meters(100cm)")
plt.xlabel("weight in Kgs")
plt.show()

plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')
plt.bar(x=people,height=weight, width=0.5,
        color='green',edgecolor='k',alpha=0.5)
plt.xlabel("People",fontsize=15)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='blue',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=14)
plt.xlabel("Weight in kgs",fontsize=14)
plt.show()

# %% [markdown]
# Part-03: Access Data from various sources and formats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
